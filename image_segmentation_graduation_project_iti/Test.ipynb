# %% [markdown]
# # Testing python files

# %% [markdown]
# ## Loading Hrnet

# %%
from hrnet import build_hrnet

model = build_hrnet((512,512,3))

# %% [markdown]
# ## Loading Unet

# %%
from unet import build_unet
import os
PATH = "D:\iti\SelfStudy\Semantic_segmentation\Semantic_Segmentation_Models"
model = build_unet((256,256,3),weights=os.path.join(PATH,'unet_20.hdf5'))

# %% [markdown]
# ## Making single image predictions

# %%
import os
from utils import predict_visualize
im = os.path.join(PATH,"CamVid\\train\\0001TP_006690.png")
pred,image,vis = predict_visualize(im,model,alpha = 0.2,plot = True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import matplotlib.pyplot as plt
plt.imshow(vis)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Making video and Gif predictions

# %%
from unet import build_unet
import os
PATH = "D:\iti\SelfStudy\Semantic_segmentation\Semantic_Segmentation_Models"
model = build_unet((256,256,3),weights=os.path.join(PATH,'unet_20.hdf5'))

from utils import createVidePrediction,createGifPrediction
createVidePrediction(model,os.path.join(PATH,"CamVid\\test"),'preds.mp4')
createGifPrediction(model,os.path.join(PATH,"CamVid\\test"),'preds.gif')
